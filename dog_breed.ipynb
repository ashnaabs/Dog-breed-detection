# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from tqdm import tqdm
from keras.utils import load_img
from keras.utils import img_to_array
from sklearn.preprocessing import label_binarize
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D
from keras.optimizers import Adam

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
labels_all = pd.read_csv("/content/dog_csv.csv")
print(labels_all.shape)
labels_all.head()
# Out:
# (930, 3)
#                         file_path             breed dataset
# 0  train/Golden Retriever/001.jpg  Golden Retriever   train
# 1  train/Golden Retriever/002.jpg  Golden Retriever   train
# 2  train/Golden Retriever/003.jpg  Golden Retriever   train
# 3  train/Golden Retriever/004.jpg  Golden Retriever   train
# 4  train/Golden Retriever/005.jpg  Golden Retriever   train

# %%
len(labels_all['breed'].unique()), labels_all['breed'].unique()
# Out:
# (7,
#  array(['Golden Retriever', 'Bermaise', 'Pug', 'Chinese Crested',
#         'Siberian Husky', 'Shih-Tzu', 'Cockapoo'], dtype=object))

# %%
# Visualize the number of each breeds
breeds_all = labels_all["breed"]
breed_counts = breeds_all.value_counts()
breed_counts.head(10)
# Out:
# Shih-Tzu            198
# Pug                 148
# Bermaise            131
# Cockapoo            129
# Golden Retriever    127
# Chinese Crested     118
# Siberian Husky       79
# Name: breed, dtype: int64

# %%
# Selecting first 5 breeds (Limitation due to computation power)
CLASS_NAMES = ['Golden Retriever','Bermaise','Pug','Chinese Crested','Siberian Husky', 'Shih-Tzu', 'Cockapoo']
labels = labels_all[(labels_all['breed'].isin(CLASS_NAMES))]
labels = labels.reset_index()
labels.head()
# Out:
#    index                       file_path             breed dataset
# 0      0  train/Golden Retriever/001.jpg  Golden Retriever   train
# 1      1  train/Golden Retriever/002.jpg  Golden Retriever   train
# 2      2  train/Golden Retriever/003.jpg  Golden Retriever   train
# 3      3  train/Golden Retriever/004.jpg  Golden Retriever   train
# 4      4  train/Golden Retriever/005.jpg  Golden Retriever   train

# %%
# !cp -r '/content/drive/MyDrive/jinshinn' '/content/'

# %%
# Creating numpy matrix with zeros
X_data = np.zeros((len(labels), 224, 224, 3), dtype='float32')
# One hot encoding
Y_data = label_binarize(labels['breed'], classes = CLASS_NAMES)

# Reading and converting image to numpy array and normalizing dataset
for i in tqdm(range(len(labels))):
    img = load_img('/content/jinshinn/' + labels['file_path'][i], target_size=(224, 224))
    img = img_to_array(img)
    x = np.expand_dims(img.copy(), axis=0)
    X_data[i] = x / 255.0

# Printing train image and one hot encode shape & size
print('\nTrain Images shape: ',X_data.shape,' size: {:,}'.format(X_data.size))
print('One-hot encoded output shape: ',Y_data.shape,' size: {:,}'.format(Y_data.size))
# Out:
# 100%|██████████| 930/930 [00:02<00:00, 375.51it/s]
# Train Images shape:  (930, 224, 224, 3)  size: 139,991,040
# One-hot encoded output shape:  (930, 7)  size: 6,510

# %%
model = Sequential()

model.add(Conv2D(filters = 64, kernel_size = (5,5), activation ='relu', input_shape = (224,224,3)))
model.add(MaxPool2D(pool_size=(2,2)))

model.add(Conv2D(filters = 32, kernel_size = (3,3), activation ='relu', kernel_regularizer = 'l2'))
model.add(MaxPool2D(pool_size=(2,2)))

model.add(Conv2D(filters = 16, kernel_size = (7,7), activation ='relu', kernel_regularizer = 'l2'))
model.add(MaxPool2D(pool_size=(2,2)))

model.add(Conv2D(filters = 8, kernel_size = (5,5), activation ='relu', kernel_regularizer = 'l2'))
model.add(MaxPool2D(pool_size=(2,2)))

model.add(Flatten())
model.add(Dense(128, activation = "relu", kernel_regularizer = 'l2'))
model.add(Dense(64, activation = "relu", kernel_regularizer = 'l2'))
model.add(Dense(len(CLASS_NAMES), activation = "softmax"))

model.compile(loss = 'categorical_crossentropy', optimizer = Adam(0.0001),metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 220, 220, 64)      4864
#
#  max_pooling2d (MaxPooling2  (None, 110, 110, 64)      0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 108, 108, 32)      18464
#
#  max_pooling2d_1 (MaxPoolin  (None, 54, 54, 32)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 48, 48, 16)        25104
#
#  max_pooling2d_2 (MaxPoolin  (None, 24, 24, 16)        0
#  g2D)
#
#  conv2d_3 (Conv2D)           (None, 20, 20, 8)         3208
#
#  max_pooling2d_3 (MaxPoolin  (None, 10, 10, 8)         0
#  g2D)
#
#  flatten (Flatten)           (None, 800)               0
#
#  dense (Dense)               (None, 128)               102528
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dense_2 (Dense)             (None, 7)                 455
#
# =================================================================
# Total params: 162879 (636.25 KB)
# Trainable params: 162879 (636.25 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Splitting the data set into training and testing data sets
X_train_and_val, X_test, Y_train_and_val, Y_test = train_test_split(X_data, Y_data, test_size = 0.1)
# Splitting the training data set into training and validation data sets
X_train, X_val, Y_train, Y_val = train_test_split(X_train_and_val, Y_train_and_val, test_size = 0.2)

# %%
# Training the model
epochs = 100
batch_size = 128

history = model.fit(X_train, Y_train, batch_size = batch_size, epochs = epochs,
                    validation_data = (X_val, Y_val))
# Out:
# Epoch 1/100
# 6/6 [==============================] - 118s 19s/step - loss: 5.7485 - accuracy: 0.1271 - val_loss: 5.6911 - val_accuracy: 0.1607
# Epoch 2/100
# 6/6 [==============================] - 98s 16s/step - loss: 5.6588 - accuracy: 0.1570 - val_loss: 5.6253 - val_accuracy: 0.1310
# Epoch 3/100
# 6/6 [==============================] - 100s 17s/step - loss: 5.5821 - accuracy: 0.1734 - val_loss: 5.5644 - val_accuracy: 0.1310
# Epoch 4/100
# 6/6 [==============================] - 100s 17s/step - loss: 5.5097 - accuracy: 0.1704 - val_loss: 5.5145 - val_accuracy: 0.1310
# Epoch 5/100
# 6/6 [==============================] - 101s 17s/step - loss: 5.4376 - accuracy: 0.1704 - val_loss: 5.4586 - val_accuracy: 0.1310
# Epoch 6/100
# 6/6 [==============================] - 103s 17s/step - loss: 5.3666 - accuracy: 0.1749 - val_loss: 5.3920 - val_accuracy: 0.2143
# Epoch 7/100
# 6/6 [==============================] - 110s 17s/step - loss: 5.2957 - accuracy: 0.2302 - val_loss: 5.3245 - val_accuracy: 0.1845
# Epoch 8/100
# 6/6 [==============================] - 100s 17s/step - loss: 5.2269 - accuracy: 0.2302 - val_loss: 5.2717 - val_accuracy: 0.1845
# Epoch 9/100
# 6/6 [==============================] - 98s 16s/step - loss: 5.1549 - accuracy: 0.2302 - val_loss: 5.2242 - val_accuracy: 0.2083
# Epoch 10/100
# 6/6 [==============================] - 101s 17s/step - loss: 5.0905 - accuracy: 0.2616 - val_loss: 5.1622 - val_accuracy: 0.2321
# Epoch 11/100
# 6/6 [==============================] - 102s 17s/step - loss: 5.0157 - accuracy: 0.2661 - val_loss: 5.0670 - val_accuracy: 0.2440
# Epoch 12/100
# 6/6 [==============================] - 100s 17s/step - loss: 4.9391 - accuracy: 0.2735 - val_loss: 5.0029 - val_accuracy: 0.2381
# Epoch 13/100
# 6/6 [==============================] - 110s 17s/step - loss: 4.8498 - accuracy: 0.3199 - val_loss: 4.9148 - val_accuracy: 0.2976
# Epoch 14/100
# 6/6 [==============================] - 100s 17s/step - loss: 4.7664 - accuracy: 0.3408 - val_loss: 4.8361 - val_accuracy: 0.2857
# Epoch 15/100
# 6/6 [==============================] - 103s 17s/step - loss: 4.6790 - accuracy: 0.3857 - val_loss: 4.8102 - val_accuracy: 0.3036
# Epoch 16/100
# 6/6 [==============================] - 106s 18s/step - loss: 4.5842 - accuracy: 0.3991 - val_loss: 4.6763 - val_accuracy: 0.3274
# Epoch 17/100
# 6/6 [==============================] - 101s 17s/step - loss: 4.4863 - accuracy: 0.4335 - val_loss: 4.6765 - val_accuracy: 0.2917
# Epoch 37/100
# 6/6 [==============================] - 105s 17s/step - loss: 3.5626 - accuracy: 0.5949 - val_loss: 3.8741 - val_accuracy: 0.4702
# Epoch 38/100
# 6/6 [==============================] - 101s 17s/step - loss: 3.5128 - accuracy: 0.5889 - val_loss: 3.8263 - val_accuracy: 0.4881
# Epoch 39/100
# 6/6 [==============================] - 102s 17s/step - loss: 3.4688 - accuracy: 0.6069 - val_loss: 3.8154 - val_accuracy: 0.4881
# Epoch 40/100
# 6/6 [==============================] - 103s 17s/step - loss: 3.4273 - accuracy: 0.6203 - val_loss: 3.7914 - val_accuracy: 0.5000
# Epoch 41/100
# 6/6 [==============================] - 106s 18s/step - loss: 3.4043 - accuracy: 0.6069 - val_loss: 3.7775 - val_accuracy: 0.5000
# Epoch 42/100
# 6/6 [==============================] - 111s 19s/step - loss: 3.3790 - accuracy: 0.6293 - val_loss: 3.7430 - val_accuracy: 0.5000
# Epoch 43/100
# 6/6 [==============================] - 108s 18s/step - loss: 3.3530 - accuracy: 0.6383 - val_loss: 3.7369 - val_accuracy: 0.4881
# Epoch 44/100
# 6/6 [==============================] - 105s 18s/step - loss: 3.3195 - accuracy: 0.6308 - val_loss: 3.7439 - val_accuracy: 0.4940
# Epoch 45/100
# 6/6 [==============================] - 105s 17s/step - loss: 3.3053 - accuracy: 0.6203 - val_loss: 3.7158 - val_accuracy: 0.4881
# Epoch 46/100
# 6/6 [==============================] - 102s 17s/step - loss: 3.2888 - accuracy: 0.6517 - val_loss: 3.7177 - val_accuracy: 0.5060
# Epoch 47/100
# 6/6 [==============================] - 105s 17s/step - loss: 3.2449 - accuracy: 0.6472 - val_loss: 3.7102 - val_accuracy: 0.5000
# Epoch 48/100
# 6/6 [==============================] - 107s 17s/step - loss: 3.2380 - accuracy: 0.6398 - val_loss: 3.6834 - val_accuracy: 0.4583
# Epoch 49/100
# 6/6 [==============================] - 101s 17s/step - loss: 3.2257 - accuracy: 0.6353 - val_loss: 3.7091 - val_accuracy: 0.4702
# Epoch 50/100
# 6/6 [==============================] - 99s 16s/step - loss: 3.1953 - accuracy: 0.6532 - val_loss: 3.6266 - val_accuracy: 0.5179
# Epoch 51/100
# 6/6 [==============================] - 102s 17s/step - loss: 3.1946 - accuracy: 0.6532 - val_loss: 3.6202 - val_accuracy: 0.4821
# Epoch 52/100
# 6/6 [==============================] - 106s 18s/step - loss: 3.1388 - accuracy: 0.6667 - val_loss: 3.6975 - val_accuracy: 0.4940
# Epoch 53/100
# 6/6 [==============================] - 101s 17s/step - loss: 3.1342 - accuracy: 0.6801 - val_loss: 3.5872 - val_accuracy: 0.5238
# Epoch 54/100
# 6/6 [==============================] - 104s 17s/step - loss: 3.0966 - accuracy: 0.6831 - val_loss: 3.6301 - val_accuracy: 0.4940
# Epoch 55/100
# 6/6 [==============================] - 106s 18s/step - loss: 3.0579 - accuracy: 0.6801 - val_loss: 3.6067 - val_accuracy: 0.5060
# Epoch 56/100
# 6/6 [==============================] - 101s 17s/step - loss: 3.0303 - accuracy: 0.6906 - val_loss: 3.6404 - val_accuracy: 0.4940
# Epoch 57/100
# 6/6 [==============================] - 102s 17s/step - loss: 3.0172 - accuracy: 0.6981 - val_loss: 3.5439 - val_accuracy: 0.4881
# Epoch 58/100
# 6/6 [==============================] - 106s 18s/step - loss: 2.9704 - accuracy: 0.6891 - val_loss: 3.6374 - val_accuracy: 0.4881
# Epoch 59/100
# 6/6 [==============================] - 101s 17s/step - loss: 2.9371 - accuracy: 0.7205 - val_loss: 3.5403 - val_accuracy: 0.5000
# Epoch 60/100
# 6/6 [==============================] - 103s 17s/step - loss: 2.9227 - accuracy: 0.7145 - val_loss: 3.6048 - val_accuracy: 0.5179
# Epoch 61/100
# 6/6 [==============================] - 101s 17s/step - loss: 2.8891 - accuracy: 0.7280 - val_loss: 3.5781 - val_accuracy: 0.5060
# Epoch 62/100
# 6/6 [==============================] - 106s 18s/step - loss: 2.8751 - accuracy: 0.7369 - val_loss: 3.5390 - val_accuracy: 0.5238
# Epoch 63/100
# 6/6 [==============================] - 101s 17s/step - loss: 2.8610 - accuracy: 0.7339 - val_loss: 3.6039 - val_accuracy: 0.5060
# Epoch 64/100
# 6/6 [==============================] - 104s 17s/step - loss: 2.8356 - accuracy: 0.7489 - val_loss: 3.5991 - val_accuracy: 0.5000
# Epoch 65/100
# 6/6 [==============================] - 110s 18s/step - loss: 2.7933 - accuracy: 0.7728 - val_loss: 3.5817 - val_accuracy: 0.5000
# Epoch 66/100
# 6/6 [==============================] - 102s 17s/step - loss: 2.8125 - accuracy: 0.7369 - val_loss: 3.5767 - val_accuracy: 0.5119
# Epoch 67/100
# 6/6 [==============================] - 100s 17s/step - loss: 2.8505 - accuracy: 0.7100 - val_loss: 3.5881 - val_accuracy: 0.4940
# Epoch 68/100
# 6/6 [==============================] - 106s 18s/step - loss: 2.8565 - accuracy: 0.7055 - val_loss: 3.6463 - val_accuracy: 0.4940
# Epoch 69/100
# 6/6 [==============================] - 101s 17s/step - loss: 2.7949 - accuracy: 0.7280 - val_loss: 3.5407 - val_accuracy: 0.5000
# Epoch 70/100
# 3/6 [==============>...............] - ETA: 56s - loss: 2.7513 - accuracy: 0.7422

# %%
model.save('dog_breedd.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
# Plot the training history
plt.figure(figsize=(12, 5))
plt.plot(history.history['accuracy'], color='r')
plt.plot(history.history['val_accuracy'], color='b')
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['train', 'val'])

plt.show()

# %%
Y_pred = model.predict(X_test)
score = model.evaluate(X_test, Y_test)
print('Accuracy over the test set: \n ', round((score[1]*100), 2), '%')
# Out:
# 2/2 [==============================] - 1s 280ms/step
# 2/2 [==============================] - 0s 18ms/step - loss: 2.6497 - accuracy: 0.7358
# Accuracy over the test set:
#   73.58 %

# %%
# Plotting image to compare
plt.imshow(X_test[1,:,:,:])
plt.show()

# Finding max value from predition list and comaparing original value vs predicted
print("Originally : ",labels['breed'][np.argmax(Y_test[1])])
print("Predicted : ",labels['breed'][np.argmax(Y_pred[1])])
# Out:
# Originally :  Golden Retriever
# Predicted :  Golden Retriever
